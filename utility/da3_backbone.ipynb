# %%
# %env HF_ENDPOINT=https://hf-mirror.com

# %%
import torch
from depth_anything_3.api import DepthAnything3
da3 = DepthAnything3.from_pretrained("depth-anything/da3-base")
da3 = da3.to("cuda")  # or "cpu"
encoder = da3.model.backbone          # type: DinoV2
encoder.eval()
